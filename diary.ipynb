# %%
pip install openai
# Out:
# Requirement already satisfied: openai in c:\users\explo\desktop\vicopare\venv\lib\site-packages (0.27.9)
# Requirement already satisfied: tqdm in c:\users\explo\desktop\vicopare\venv\lib\site-packages (from openai) (4.66.1)
# Requirement already satisfied: aiohttp in c:\users\explo\desktop\vicopare\venv\lib\site-packages (from openai) (3.8.5)
# Requirement already satisfied: requests>=2.20 in c:\users\explo\desktop\vicopare\venv\lib\site-packages (from openai) (2.31.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\explo\desktop\vicopare\venv\lib\site-packages (from requests>=2.20->openai) (2023.7.22)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\explo\desktop\vicopare\venv\lib\site-packages (from requests>=2.20->openai) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\explo\desktop\vicopare\venv\lib\site-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\explo\desktop\vicopare\venv\lib\site-packages (from requests>=2.20->openai) (3.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\explo\desktop\vicopare\venv\lib\site-packages (from aiohttp->openai) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\explo\desktop\vicopare\venv\lib\site-packages (from aiohttp->openai) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\explo\desktop\vicopare\venv\lib\site-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\explo\desktop\vicopare\venv\lib\site-packages (from aiohttp->openai) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\explo\desktop\vicopare\venv\lib\site-packages (from aiohttp->openai) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\explo\desktop\vicopare\venv\lib\site-packages (from aiohttp->openai) (23.1.0)
# Requirement already satisfied: colorama in c:\users\explo\desktop\vicopare\venv\lib\site-packages (from tqdm->openai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# connect to openai
import os
import openai

from config import OPENAI_Settings

openai_settings = OPENAI_Settings()

MYTESTKEY = openai_settings.mytestkey
ORGANIZATION_NAME = openai_settings.organization
ORGANIZATION_ID = openai_settings.organization_id

openai.organization = ORGANIZATION_ID
openai.api_key = MYTESTKEY
# Out:
#                                id object     created         owned_by  \
# 0                         davinci  model  1649359874           openai
# 1                text-davinci-001  model  1649364042           openai
# 2     text-search-curie-query-001  model  1651172509       openai-dev
# 3                   gpt-3.5-turbo  model  1677610602           openai
# 4                         babbage  model  1649358449           openai
# 5                text-babbage-001  model  1649364043           openai
# 6             curie-instruct-beta  model  1649364042           openai
# 7              davinci-similarity  model  1651172509       openai-dev
# 8           code-davinci-edit-001  model  1649880484           openai
# 9       text-similarity-curie-001  model  1651172507       openai-dev
# 10           ada-code-search-text  model  1651172510       openai-dev
# 11             gpt-3.5-turbo-0613  model  1686587434           openai
# 12      text-search-ada-query-001  model  1651172505       openai-dev
# 13         gpt-3.5-turbo-16k-0613  model  1685474247           openai
# 14           babbage-search-query  model  1651172509       openai-dev
# 15                 ada-similarity  model  1651172507       openai-dev
# 16                 text-curie-001  model  1649364043           openai
# 17                          gpt-4  model  1687882411           openai
# 18              gpt-3.5-turbo-16k  model  1683758102  openai-internal
# 19        text-search-ada-doc-001  model  1651172507       openai-dev
# 20  text-search-babbage-query-001  model  1651172509       openai-dev
# 21       code-search-ada-code-001  model  1651172507       openai-dev
# 22          curie-search-document  model  1651172508       openai-dev
# 23                    davinci-002  model  1692634301           system
# 24  text-search-davinci-query-001  model  1651172505       openai-dev
# 25      text-search-curie-doc-001  model  1651172509       openai-dev
# 26        babbage-search-document  model  1651172510       openai-dev
# 27                    babbage-002  model  1692634615           system
# 28       babbage-code-search-text  model  1651172509       openai-dev
# 29         text-embedding-ada-002  model  1671217299  openai-internal
# 30          davinci-instruct-beta  model  1649364042           openai
# 31           davinci-search-query  model  1651172505       openai-dev
# 32    text-similarity-babbage-001  model  1651172505       openai-dev
# 33                     gpt-4-0314  model  1687882410           openai
# 34               text-davinci-002  model  1649880484           openai
# 35   code-search-babbage-text-001  model  1651172507       openai-dev
# 36               text-davinci-003  model  1669599635  openai-internal
# 37    text-search-davinci-doc-001  model  1651172505       openai-dev
# 38       code-search-ada-text-001  model  1651172507       openai-dev
# 39               ada-search-query  model  1651172505       openai-dev
# 40        text-similarity-ada-001  model  1651172505       openai-dev
# 41                     gpt-4-0613  model  1686588896           openai
# 42           ada-code-search-code  model  1651172505       openai-dev
# 43                      whisper-1  model  1677532384  openai-internal
# 44          text-davinci-edit-001  model  1649809179           openai
# 45        davinci-search-document  model  1651172509       openai-dev
# 46             curie-search-query  model  1651172509       openai-dev
# 47             babbage-similarity  model  1651172505       openai-dev
# 48                            ada  model  1649357491           openai
# 49            ada-search-document  model  1651172507       openai-dev
#
#                                            permission  \
# 0   [{'id': 'modelperm-uJaD4C9nXA6tPNoBII9hcYF4', ...
# 1   [{'id': 'modelperm-CDlahk1RbkghXDjtxqzXoPNo', ...
# 2   [{'id': 'modelperm-fNgpMH6ZEQulSq1CjzlfQuIe', ...
# 3   [{'id': 'modelperm-aRL68Vu37kh2Z0wi2tmPhGZT', ...
# 4   [{'id': 'modelperm-h574xGeqWyBeFDDKaoVTC4CO', ...
# 5   [{'id': 'modelperm-YABzYWjC1kS6M2BnI6Fr9vuS', ...
# 6   [{'id': 'modelperm-4GYfzAdSMcJmQvF7bsw01UWw', ...
# 7   [{'id': 'modelperm-XHJ9P2cvfDAl6Q6NABs6wD7G', ...
# 8   [{'id': 'modelperm-T8Ie7SvlPyvtsDvPlfC8DftZ', ...
# 9   [{'id': 'modelperm-ZQZGhVQCQSN4WC1wRJsFZfRL', ...
# 10  [{'id': 'modelperm-jWFKGhnNYXhMIJuYYBe8zKoH', ...
# 11  [{'id': 'modelperm-t8jT1BkYxMNFFB57ndHNpyfP', ...
# 12  [{'id': 'modelperm-YO36k119sJYqPB8yHh737z8l', ...
# 13  [{'id': 'modelperm-hb67ObpoaFIKTieIMs9CqZPq', ...
# 14  [{'id': 'modelperm-o5hcKERXLlTSB0nfq8fPkAzK', ...
# 15  [{'id': 'modelperm-Tz8CgePTpeDdl0q0mDxAseS4', ...
# 16  [{'id': 'modelperm-epkpKCMZ4ezExtQH69gwuIVE', ...
# 17  [{'id': 'modelperm-P7lby9Sdb6rLW8qqie46YnE0', ...
# 18  [{'id': 'modelperm-BPjHua9GyiXIbj7F0M6c4j0A', ...
# 19  [{'id': 'modelperm-WQoo7GOoaleCrrerQ8ROIejy', ...
# 20  [{'id': 'modelperm-PHk5XyJIMEk88v14M2eEcJfE', ...
# 21  [{'id': 'modelperm-lPJ8tQWzTuRpZpOjtRN4CjlP', ...
# 22  [{'id': 'modelperm-o3nt5yDhE7FpA8PtMlzGuW3k', ...
# 23  [{'id': 'modelperm-i5MgZCdMtQ4dZeuGaY9cZ6zG', ...
# 24  [{'id': 'modelperm-X2U9yi1RKudh1hGQ9CnPth2A', ...
# 25  [{'id': 'modelperm-7mOkCIwOIehlltLDPM1oSKN7', ...
# 26  [{'id': 'modelperm-FQiAIZXWHZ4yJl6b4X0JWpfw', ...
# 27  [{'id': 'modelperm-tC8uL3ohDEVSzUvcgZCv33gV', ...
# 28  [{'id': 'modelperm-9AyTgRlbDLetEnvXKDgJvSvR', ...
# 29  [{'id': 'modelperm-6xIVIGILGxg9gTVWY0SpzkFn', ...
# 30  [{'id': 'modelperm-ZNpXjNy0lDniBWzpvi6w6wSU', ...
# 31  [{'id': 'modelperm-w5yjX7u1Hgz0jJFhPRB93n6I', ...
# 32  [{'id': 'modelperm-8p0vOyyD6xVDYv6XOC4EYIin', ...
# 33  [{'id': 'modelperm-b21ASphHKebBmLgaknIEPuP0', ...
# 34  [{'id': 'modelperm-Ao62Dd2uu76ec6Koq1ksR2rj', ...
# 35  [{'id': 'modelperm-uH251hsudZq0DqxtTcSYFTcD', ...
# 36  [{'id': 'modelperm-8tPGPaSHf5yGydNlBlyWKtFw', ...
# 37  [{'id': 'modelperm-sqcSr7AYu6WYtzWgysHg1zO4', ...
# 38  [{'id': 'modelperm-1JbI0GFKw9luPgTJQut1uJNe', ...
# 39  [{'id': 'modelperm-cBtmsjrTZIJUKgjS8G6uALKM', ...
# 40  [{'id': 'modelperm-fSDlSniO72T5MvD6ieDRue0a', ...
# 41  [{'id': 'modelperm-RYFZEfYeoUcXzGVvODKh87Hy', ...
# 42  [{'id': 'modelperm-469coJJMBDffmGlbftht9QR7', ...
# 43  [{'id': 'modelperm-Qbzvr0DnIyt2HdaFiLj0P5h4', ...
# 44  [{'id': 'modelperm-bwEWUtGiBcdX0p1D1ayafH8w', ...
# 45  [{'id': 'modelperm-1jEFSTL1yLUnTyI8TekKPGQF', ...
# 46  [{'id': 'modelperm-fvYLh7mrZBoEXRa9teCq7ZsK', ...
# 47  [{'id': 'modelperm-XBmFjRKu34Qvm9Y8Vjg6si3V', ...
# 48  [{'id': 'modelperm-gUTBN2NFYvvG3UwNeDnY6EEe', ...
# 49  [{'id': 'modelperm-jEtYYVTVutQ4BLh2DnGd9tJt', ...
#
#                              root parent
# 0                         davinci   None
# 1                text-davinci-001   None
# 2     text-search-curie-query-001   None
# 3                   gpt-3.5-turbo   None
# 4                         babbage   None
# 5                text-babbage-001   None
# 6             curie-instruct-beta   None
# 7              davinci-similarity   None
# 8           code-davinci-edit-001   None
# 9       text-similarity-curie-001   None
# 10           ada-code-search-text   None
# 11             gpt-3.5-turbo-0613   None
# 12      text-search-ada-query-001   None
# 13         gpt-3.5-turbo-16k-0613   None
# 14           babbage-search-query   None
# 15                 ada-similarity   None
# 16                 text-curie-001   None
# 17                          gpt-4   None
# 18              gpt-3.5-turbo-16k   None
# 19        text-search-ada-doc-001   None
# 20  text-search-babbage-query-001   None
# 21       code-search-ada-code-001   None
# 22          curie-search-document   None
# 23                    davinci-002   None
# 24  text-search-davinci-query-001   None
# 25      text-search-curie-doc-001   None
# 26        babbage-search-document   None
# 27                    babbage-002   None
# 28       babbage-code-search-text   None
# 29         text-embedding-ada-002   None
# 30          davinci-instruct-beta   None
# 31           davinci-search-query   None
# 32    text-similarity-babbage-001   None
# 33                     gpt-4-0314   None
# 34               text-davinci-002   None
# 35   code-search-babbage-text-001   None
# 36               text-davinci-003   None
# 37    text-search-davinci-doc-001   None
# 38       code-search-ada-text-001   None
# 39               ada-search-query   None
# 40        text-similarity-ada-001   None
# 41                     gpt-4-0613   None
# 42           ada-code-search-code   None
# 43                      whisper-1   None
# 44          text-davinci-edit-001   None
# 45        davinci-search-document   None
# 46             curie-search-query   None
# 47             babbage-similarity   None
# 48                            ada   None
# 49            ada-search-document   None

# %%
# check model list
models = openai.Model.list()

import pandas as pd
data = pd.DataFrame(models["data"])
print(data.head(50))

# %% [markdown]
# https://analyzingalpha.com/openai-api-python-tutorial
# OpenAI uses DALL-E models for image processing tasks.
# The image API currently provides methods for three image-processing tasks:
#
# 1. Generating images from text.
# 2. Editing images based on text instructions
# 3. Generate image variations.

# %%
# 일기 요약

# %%
# 요약된 일기를 그림으로 생성
prompt_text = "visual coding power ladies"
response = openai.Image.create(
  prompt= prompt_text,
  n=2,
  size="512x512"
)

for image in response['data']:
    print(image['url'])
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-yjX2CKo6pDNZKaCW8akcD6U3/user-BO9v4mlPUVGed8aFseZPreg3/img-I8s1JjWfFoW482ak0HQXBAmP.png?st=2023-08-29T13%3A13%3A04Z&se=2023-08-29T15%3A13%3A04Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-08-29T02%3A06%3A10Z&ske=2023-08-30T02%3A06%3A10Z&sks=b&skv=2021-08-06&sig=3O3KOiV5qmgYPDWYgS/H4ddf1PR3i%2B3vdqKA3IdwaQg%3D
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-yjX2CKo6pDNZKaCW8akcD6U3/user-BO9v4mlPUVGed8aFseZPreg3/img-oJ8y5fG14RS7QLlS7kGwaxB8.png?st=2023-08-29T13%3A13%3A04Z&se=2023-08-29T15%3A13%3A04Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-08-29T02%3A06%3A10Z&ske=2023-08-30T02%3A06%3A10Z&sks=b&skv=2021-08-06&sig=nQJBKagEEowhhgnrcbZSH%2B%2Bv4/0j/Y2kzPjgmYpmgOc%3D
